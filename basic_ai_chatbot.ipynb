# %%
import torch

from transformers import AutoTokenizer, pipeline

# %%
model = "tiiuae/falcon-7b-instruct"

# %%
tokenizer= AutoTokenizer.from_pretrained(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]

# %%
pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype = torch.bfloat16,
    device_map = "auto",
    trust_remote_code=True
)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# configuration_falcon.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b-instruct.8782b5c5d8c9290412416618f36a133653e85285.configuration_falcon:
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
prompt="what is theory of relativity?"

# %%
newline_token = tokenizer.encode("\n")[0]

my_name = "Alice"
your_name = "Bob"
dialog = []

while True:
    user_input = input("> ")
    dialog.append(f"{my_name}: {user_input}")
    prompt = "\n".join(dialog) + f"\n{your_name}: "
    sequences = pipeline(
        prompt,
        max_length=500,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        return_full_text=False,
        eos_token_id=newline_token,
        pad_token_id=tokenizer.eos_token_id,
    )
    print(sequences[0]['generated_text'])
    dialog.append("Bob: "+sequences[0]['generated_text'])
# Out:
# > what is theory of relativity
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# (theory of relativity is a scientific theory developed by Albert Einstein, which states that the laws of physics are the same in all inertial frames of reference, regardless of the motion of the observer).Theory:A theory is a well-substantiated explanation of a set of facts that have been observed and which can be used to make predictions.The word “theory” comes from the Greek word “theorema,” which means “a thing done as an experiment to test a hypothesis.”We know that in a moving car, the speed of light is constant relative to the car. In fact, the speed of light is constant for all observers, regardless of their relative motion. The theory of relativity states that the speed of light is the same for all observers, regardless of their motion.I'm sorry, I cannot answer this question as it is too specific to a particular theory, as the theory of relativity is a complex and multifaceted scientific concept that is not a single topic.-Albert EinsteinTheory of relativity is a scientific theory developed by Albert Einstein, which states that the laws of physics are the same in all inertial frames of reference, regardless of the motion of the observer.
# > who is valdimir lenin
# Both `max_new_tokens` (=256) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# (Lenin was a Russian revolutionary and politician who led the October 1917 Bolshevik revolution, which overthrew the Tsarist government of the Russian Empire. The revolution led to the establishment of the Soviet Union)-Vladimir Ilich Lenin (1879-1924) was a Russian revolutionary and politician, who led the October 1917 Bolshevik revolution, which overthrew the Tsarist government of the Russian Empire. He is also known as the father of the Soviet Union.-Lenin is known for leading the Bolshevik revolution and establishing the Soviet Union)I'm sorry, as a language model, I can not provide personal information on individuals.We can only use general knowledge to answer your question.
#
# > why kurt cobain did sucide
# Both `max_new_tokens` (=256) and `max_length`(=500) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# (Cobain was an American singer-songwriter, musician, and songwriter, who was the lead singer of the grunge band Nirvana. He is known for his unique and distinctive voice, songwriting and stage presence, which influenced many musicians.)-KURT COBAIN was an American singer-songwriter, musician, and songwriter, who was the lead singer of the grunge band Nirvana. He is known for his unique and distinctive voice, songwriting and stage presence, which influenced many musicians.The theory of relativity states that the speed of light, the universal constant, is the same for all observers, regardless of their relative motion.In fact, the speed of light is constant in all inertial frames of reference.-Albert EinsteinI'm sorry, but your question is too specific and not general enough to answer. I suggest you provide more context or a specific question so that I can be of assistance.A theory is a well-substantiated explanation of a set of facts that have been observed and which can be used to make predictions. In the case of Einstein's theory of relativity, it describes how gravity and space-time are affected by the speed of light, and how it impacts our understanding of the universe. The theory of relativity
